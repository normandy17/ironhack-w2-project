# %%
import sys
sys.path.append(r"C:\Ironhack\ironhack-w2-project\pre-processing")
from preProcessing import one_hot_encode_date

C:\Ironhack\ironhack-w2-project\training.csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import sys
#       2 sys.path.append(r"C:\Ironhack\ironhack-w2-project\pre-processing")
# ----> 3 from preProcessing import one_hot_encode_date
#
# ModuleNotFoundError: No module named 'preProcessing'
